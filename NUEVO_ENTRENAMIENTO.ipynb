# %% [markdown]
# <a href="https://colab.research.google.com/github/Vengadore/NVD_in_OpticDisc/blob/main/NUEVO_ENTRENAMIENTO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -O "NVD.rar" "https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/Ed-LPgdRBcJPqE2Xal6yqUgBGeQApkmNPk6u4OiuYnwtTg?download=1"
# Out:
# --2021-09-09 15:40:27--  https://correoipn-my.sharepoint.com/:u:/g/personal/ccarrillog1400_alumno_ipn_mx/Ed-LPgdRBcJPqE2Xal6yqUgBGeQApkmNPk6u4OiuYnwtTg?download=1
# Resolving correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)... 13.107.136.9, 13.107.138.9
# Connecting to correoipn-my.sharepoint.com (correoipn-my.sharepoint.com)|13.107.136.9|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/ccarrillog1400_alumno_ipn_mx/Documents/Data%20Bases/NVD.rar?originalPath=aHR0cHM6Ly9jb3JyZW9pcG4tbXkuc2hhcmVwb2ludC5jb20vOnU6L2cvcGVyc29uYWwvY2NhcnJpbGxvZzE0MDBfYWx1bW5vX2lwbl9teC9FZC1MUGdkUkJjSlBxRTJYYWw2eXFVZ0JHZVFBcGttTlBrNnU0T2l1WW53dFRnP3J0aW1lPWJuUDhKYWh6MlVn [following]
# ...

# %%
# !unrar x NVD.rar
cd NVD
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from NVD.rar
#
# Creating    NVD                                                       OK
# Creating    NVD/.git                                                  OK
#   OK
#   OK
#   OK
#   OK
# Creating    NVD/.git/hooks                                            OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    NVD/.git/info                                             OK
#   OK
# Creating    NVD/.git/logs                                             OK
#   OK
# Creating    NVD/.git/logs/refs                                        OK
# Creating    NVD/.git/logs/refs/heads                                  OK
#   OK
# Creating    NVD/.git/logs/refs/remotes                                OK
# Creating    NVD/.git/logs/refs/remotes/origin                         OK
#   OK
# Creating    NVD/.git/objects                                          OK
# ...

# %%
# !python train.py
# Out:
# Le module de correlation n'a pas pu être importé, PWC-Net ne pourra pas être utilisé.
# Le module de correlation n'a pas pu être importé, PWC-Net ne pourra pas être utilisé.
# Le module de correlation n'a pas pu être importé, PWC-Net ne pourra pas être utilisé.
# Buscando base de datos en ./Base de datos/OpticDiscs/
# Datos de entrenamiento:
# 0    76
# 1    73
# Name: class, dtype: int64
# Datos de validación:
# 1    59
# 0    53
# Name: class, dtype: int64
# Datos de test:
# 0    58
# 1    55
# Name: class, dtype: int64
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:04<00:00, 114MB/s]
# Loaded VGG-16 weights in Segnet !
# Traceback (most recent call last):
#   File "train.py", line 78, in <module>
#     model = segnet(INPUT_CHANNELS,OUTPUT_CHANNELS,True).cuda(0)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 637, in cuda
# ...
